# %%
import pandas as pd
import plotly.express as px

# Load the CSV file
df = pd.read_csv('suss_courses.csv')
df.head()
# Out:
#                                                title code  \
# 0        Graduate Diploma in Curriculum and Teaching  NaN
# 1                      Graduate Diploma in Education  NaN
# 2                                Master of Education  NaN
# 3  Graduate Diploma in Learning Design and Techno...  NaN
# 4                 Doctor of Philosophy (Gerontology)  NaN
#
#                                                  url             types  \
# 0  https://www.suss.edu.sg/programmes/detail/grad...  Graduate Studies
# 1  https://www.suss.edu.sg/programmes/detail/grad...  Graduate Studies
# 2  https://www.suss.edu.sg/programmes/detail/mast...  Graduate Studies
# 3  https://www.suss.edu.sg/programmes/detail/grad...  Graduate Studies
# 4  https://www.suss.edu.sg/programmes/detail/phd-...  Graduate Studies
#
#    featured applications_open applications_close  intake duration fees  \
# 0      True         16-Apr-25          15-Oct-25  Jan-26      NaN  NaN
# 1      True         16-Apr-25          15-Oct-25  Jan-26      NaN  NaN
# 2      True         16-Apr-25          15-Oct-25  Jan-26      NaN  NaN
# 3      True         16-Apr-26          15-Oct-26  Jan-27      NaN  NaN
# 4     False         16-Apr-24          15-Apr-25  Jul-25      NaN  NaN
#
#   area_of_interest
# 0   Adult Learning
# 1   Adult Learning
# 2   Adult Learning
# 3   Adult Learning
# 4      Gerontology

# %%
len(df)
# Out:
# 1423

# %% [markdown]
# # Course Type
#
# Most courses are categorized under IHL Micro-Credentials, Modular Undergraduate Courses (610), followed by Modular Undergraduate Courses (209) and IHL Micro-Credentials, Modular Graduate Courses (190). Other common types include Modular Graduate Courses (97), Graduate Studies (66), and Short Courses with SkillsFuture Series (54). Fewer courses fall under types like Law Programmes and Certificate Courses.

# %%
# Count course types
type_counts = df['types'].value_counts().reset_index()
type_counts.columns = ['Course Type', 'Number of Courses']
type_counts = type_counts.sort_values('Number of Courses', ascending=True)  # for horizontal layout

# Create horizontal bar chart
fig = px.bar(
    type_counts,
    x='Number of Courses',
    y='Course Type',
    orientation='h',
    text='Number of Courses',
    color='Number of Courses',
    color_continuous_scale='Blues'
)

# Beautify the chart
fig.update_layout(
    title='Number of Courses by Type',
    title_x=0.5,
    xaxis_title='Number of Courses',
    yaxis_title='',
    font=dict(family='Arial', size=14),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False
)

fig.update_traces(textposition='outside')

# Show chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93b7074a-61c8-4747-a846-959d1482a171" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93b7074a-61c8-4747-a846-959d1482a171")) {                    Plotly.newPlot(                        "93b7074a-61c8-4747-a846-959d1482a171",                        [{"alignmentgroup":"True","hovertemplate":"Number of Courses=%{marker.color}\u003cbr\u003eCourse Type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,2,3,5,6,6,12,25,29,29,34,43,54,66,97,190,209,610],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[2.0,2.0,3.0,5.0,6.0,6.0,12.0,25.0,29.0,29.0,34.0,43.0,54.0,66.0,97.0,190.0,209.0,610.0],"textposition":"outside","x":[2,2,3,5,6,6,12,25,29,29,34,43,54,66,97,190,209,610],"xaxis":"x","y":["Certificate Course, Modular Graduate Course","Law Programmes","Certificate Course, IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Modular Graduate Course, SkillsFuture Series","Certificate Course, IHL Micro-Credentials, Modular Graduate Course","Modular Undergraduate Course, SkillsFuture Series","Full-time Undergraduate","Graduate Certificate","IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Short Course","Part-time Undergraduate","IHL Micro-Credentials, Modular Undergraduate Course, SkillsFuture Series","Short Course, SkillsFuture Series","Graduate Studies","Modular Graduate Course","IHL Micro-Credentials, Modular Graduate Course","Modular Undergraduate Course","IHL Micro-Credentials, Modular Undergraduate Course"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type": ...

# %% [markdown]
# “IHL Micro-Credentials, Modular Undergraduate Course” accounts for the largest share at 42.9% (610 courses), followed by “Modular Undergraduate Course” (209, 14.7%) and “IHL Micro-Credentials, Modular Graduate Course” (190, 13.4%). The remaining course types each contribute less than 10% individually.

# %%
fig = px.pie(type_counts, names='Course Type', values='Number of Courses', title='Course Type Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="445684c3-7e29-4b3c-af74-af037d4d6387" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("445684c3-7e29-4b3c-af74-af037d4d6387")) {                    Plotly.newPlot(                        "445684c3-7e29-4b3c-af74-af037d4d6387",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Course Type=%{label}\u003cbr\u003eNumber of Courses=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Certificate Course, Modular Graduate Course","Law Programmes","Certificate Course, IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Modular Graduate Course, SkillsFuture Series","Certificate Course, IHL Micro-Credentials, Modular Graduate Course","Modular Undergraduate Course, SkillsFuture Series","Full-time Undergraduate","Graduate Certificate","IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Short Course","Part-time Undergraduate","IHL Micro-Credentials, Modular Undergraduate Course, SkillsFuture Series","Short Course, SkillsFuture Series","Graduate Studies","Modular Graduate Course","IHL Micro-Credentials, Modular Graduate Course","Modular Undergraduate Course","IHL Micro-Credentials, Modular Undergraduate Course"],"legendgroup":"","name":"","showlegend":true,"values":[2,2,3,5,6,6,12,25,29,29,34,43,54,66,97,190,209,610],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777 ...

# %% [markdown]
# # Number of Courses by Area of Interest
#
# Business Administration has the highest number of courses (265), followed by Linguistics and Languages (201), Management (184), and Finance (126). Other notable areas include Social Services, Digital Media, and Science and Technology, while fields like Legal and International Trade have relatively few courses.

# %%
# Count area of interest
area_counts = df['area_of_interest'].value_counts().reset_index()
area_counts.columns = ['Area of Interest', 'Number of Courses']

# Sort for better visualization (already sorted but you can reverse if needed)
area_counts = area_counts.sort_values(by='Number of Courses', ascending=True)

# Create horizontal bar chart
fig = px.bar(
    area_counts,
    x='Number of Courses',
    y='Area of Interest',
    orientation='h',  # Horizontal bars
    text='Number of Courses',
    title='Number of Courses by Area of Interest',
    color='Number of Courses',
    color_continuous_scale='Blues'
)

# Beautify
fig.update_layout(
    xaxis_title='Number of Courses',
    yaxis_title='',
    font=dict(family="Arial", size=14),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    title_x=0.5
)
fig.update_traces(textposition='outside')

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c4433f2c-75a1-45c6-942e-21efa56c9fd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4433f2c-75a1-45c6-942e-21efa56c9fd3")) {                    Plotly.newPlot(                        "c4433f2c-75a1-45c6-942e-21efa56c9fd3",                        [{"alignmentgroup":"True","hovertemplate":"Number of Courses=%{marker.color}\u003cbr\u003eArea of Interest=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,3,6,10,12,12,14,19,42,44,47,55,58,61,69,79,114,126,184,201,265],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[2.0,3.0,6.0,10.0,12.0,12.0,14.0,19.0,42.0,44.0,47.0,55.0,58.0,61.0,69.0,79.0,114.0,126.0,184.0,201.0,265.0],"textposition":"outside","x":[2,3,6,10,12,12,14,19,42,44,47,55,58,61,69,79,114,126,184,201,265],"xaxis":"x","y":["Legal","Compliance","International Trade","Information Technology","To be confirmed","Design","Special Education","Gerontology","Business Administration, International Trade, Science and Technology","General Studies","Digital Media","Built Environment","Social Services","Adult Learning","Finance","Others","Management","Humanities and Social Sciences","Linguistics and Languages","Science and Technology","Business Administration"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...

# %% [markdown]
# # Featured Courses
#
# The recommended courses primarily fall under the Adult Learning domain, including programmes such as the Graduate Diploma in Curriculum and Teaching, Graduate Diploma in Education, and Master of Education. In addition, short-term, high-value offerings in Information Technology (e.g., Introduction to Generative Artificial Intelligence) and Sustainability (e.g., Carbon Management – A Systematic Approach to Manage Greenhouse Gas Emissions) are priced at SGD 700 per day, underscoring their strategic importance and relevance to emerging national and global priorities.

# %%
# Filter rows where 'featured' is TRUE (case-insensitive if stored as strings)
featured_courses = df[df['featured'].astype(str).str.upper() == 'TRUE']
featured_courses
# Out:
#                                                  title      code  \
# 0          Graduate Diploma in Curriculum and Teaching       NaN
# 1                        Graduate Diploma in Education       NaN
# 2                                  Master of Education       NaN
# 3    Graduate Diploma in Learning Design and Techno...       NaN
# 12   Graduate Diploma in Learning Design and Techno...       NaN
# 151  Carbon Management – A Systematic Approach to M...  (CET258)
# 152  Introduction to Generative Artificial Intellig...  (CET175)
#
#                                                    url  \
# 0    https://www.suss.edu.sg/programmes/detail/grad...
# 1    https://www.suss.edu.sg/programmes/detail/grad...
# 2    https://www.suss.edu.sg/programmes/detail/mast...
# 3    https://www.suss.edu.sg/programmes/detail/grad...
# 12   https://www.suss.edu.sg/programmes/detail/grad...
# 151  https://www.suss.edu.sg/courses/short-course/d...
# 152  https://www.suss.edu.sg/courses/short-course/d...
#
#                                  types  featured applications_open  \
# 0                     Graduate Studies      True         16-Apr-25
# 1                     Graduate Studies      True         16-Apr-25
# 2                     Graduate Studies      True         16-Apr-25
# 3                     Graduate Studies      True         16-Apr-26
# 12                    Graduate Studies      True         16-Apr-26
# 151  Short Course, SkillsFuture Series      True         14-Mar-25
# 152  Short Course, SkillsFuture Series      True         12-Sep-24
#
#     applications_close     intake duration   fees        area_of_interest
# 0            15-Oct-25     Jan-26      NaN    NaN          Adult Learning
# 1            15-Oct-25     Jan-26      NaN    NaN          Adult Learning
# 2            15-Oct-25     Jan-26      NaN    NaN          Adult Learning
# 3            15-Oct-26     Jan-27      NaN    NaN          Adult Learning
# 12           15-Oct-26     Jan-27      NaN    NaN          Adult Learning
# 151          19-Jun-25  10-Jul-25   2 days  $1400                  Others
# 152          13-Nov-24  04-Dec-24    1 day   $700  Information Technology

# %%
pd.set_option('display.max_colwidth', None)

# %%
featured_courses[['title', 'area_of_interest','fees']]
# Out:
#                                                                             title  \
# 0                                     Graduate Diploma in Curriculum and Teaching
# 1                                                   Graduate Diploma in Education
# 2                                                             Master of Education
# 3                              Graduate Diploma in Learning Design and Technology
# 12                             Graduate Diploma in Learning Design and Technology
# 151  Carbon Management – A Systematic Approach to Manage Greenhouse Gas Emissions
# 152                       Introduction to Generative Artificial Intelligence (AI)
#
#            area_of_interest   fees
# 0            Adult Learning    NaN
# 1            Adult Learning    NaN
# 2            Adult Learning    NaN
# 3            Adult Learning    NaN
# 12           Adult Learning    NaN
# 151                  Others  $1400
# 152  Information Technology   $700

# %% [markdown]
# # Duration
# As programme listings do not indicate course durations, the following analysis pertains solely to courses under the 'Courses' category. Notably, over 93% of these courses are structured with a standard duration of six months. Only a small proportion deviate from this norm, with shorter or longer durations being relatively rare.

# %%
# Count the number of courses by duration
duration_counts = df['duration'].value_counts().reset_index()
duration_counts.columns = ['Duration', 'Number of Courses']
duration_counts = duration_counts.sort_values('Number of Courses', ascending=True)

# Create horizontal bar chart
fig = px.bar(
    duration_counts,
    x='Number of Courses',
    y='Duration',
    orientation='h',
    text='Number of Courses',
    color='Number of Courses',
    color_continuous_scale='PuBu'
)

# Beautify layout
fig.update_layout(
    title='Number of Courses by Duration',
    title_x=0.5,
    xaxis_title='Number of Courses',
    yaxis_title='',
    font=dict(family='Arial', size=14),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False
)
fig.update_traces(textposition='outside')

# Show it
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c60a5572-9f04-4df9-a5de-96515b092206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c60a5572-9f04-4df9-a5de-96515b092206")) {                    Plotly.newPlot(                        "c60a5572-9f04-4df9-a5de-96515b092206",                        [{"alignmentgroup":"True","hovertemplate":"Number of Courses=%{marker.color}\u003cbr\u003eDuration=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,1,1,3,9,12,25,35,1197],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[1.0,1.0,1.0,3.0,9.0,12.0,25.0,35.0,1197.0],"textposition":"outside","x":[1,1,1,3,9,12,25,35,1197],"xaxis":"x","y":["30 months","3 full days","4 x half-day","12 months","3 days","4 days","2 days","1 day","6 months"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"li ...

# %%
# Calculate percent
duration_counts['Percent'] = (duration_counts['Number of Courses'] / duration_counts['Number of Courses'].sum() * 100).round(2)

# Create conditional labels
duration_counts['Label'] = duration_counts.apply(
    lambda row: f"{row['Duration']}<br>{row['Percent']}%" if row['Percent'] > 3 else '',
    axis=1
)

# Sort and color
duration_counts = duration_counts.sort_values(by='Number of Courses', ascending=True)
colors = px.colors.sequential.Blues[-len(duration_counts):]

# Create the pie chart (no hover_data param)
fig = px.pie(
    duration_counts,
    names='Duration',
    values='Number of Courses',
    title='Distribution of Courses by Duration',
    color=duration_counts['Duration'],
    color_discrete_sequence=colors
)

# Add percent as customdata for formatted tooltip
fig.update_traces(
    text=duration_counts['Label'],
    textinfo='text',
    customdata=duration_counts[['Percent']],
    hovertemplate="<b>%{label}</b><br>Number of Courses: %{value}<br>Percent: %{customdata[0]}%"
)

fig.update_layout(title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ed41a69a-8be2-4684-baf4-3daea674cb7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed41a69a-8be2-4684-baf4-3daea674cb7c")) {                    Plotly.newPlot(                        "ed41a69a-8be2-4684-baf4-3daea674cb7c",                        [{"customdata":[[0.08],[0.08],[0.08],[0.23],[0.7],[0.93],[1.95],[2.73],[93.22]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eNumber of Courses: %{value}\u003cbr\u003ePercent: %{customdata[0]}%","labels":["30 months","3 full days","4 x half-day","12 months","3 days","4 days","2 days","1 day","6 months"],"legendgroup":"","marker":{"colors":["rgb(247,251,255)","rgb(222,235,247)","rgb(198,219,239)","rgb(158,202,225)","rgb(107,174,214)","rgb(66,146,198)","rgb(33,113,181)","rgb(8,81,156)","rgb(8,48,107)"]},"name":"","showlegend":true,"values":[1,1,1,3,9,12,25,35,1197],"type":"pie","text":["","","","","","","","","6 months\u003cbr\u003e93.22%"],"textinfo":"text"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl ...

# %% [markdown]
# # Fees
# As programme listings do not provide fee information, the following data on course fees is based solely on courses listed under the 'Courses' category.
#
# ## Course Fee Distribution Summary
# As programme listings do not indicate fees, the following analysis pertains solely to courses under the 'Courses' category. The distribution of course fees shows that 25% of courses are priced below 1392 SGD (Q1), while the median fee is 1461 SGD—indicating that half of all courses cost less than this amount and half cost more. Additionally, 75% of courses are priced below 1936 SGD (Q3). Any course with a fee above 2676 SGD is considered an outlier, with the highest recorded fee reaching 7875 SGD.
#
# | Name             | Value (SGD) | Explanation                                                                 |
# |------------------|-------------|------------------------------------------------------------------------------|
# | **min**          | 0           |  Programme listings do not provide fee information                |
# | **Q1 (25%)**     | 1392        | 25% of courses have fees lower than 1392 SGD                                |
# | **Median (50%)** | 1461        | The middle value — half the courses are cheaper, half are more expensive    |
# | **Q3 (75%)**     | 1936        | 75% of courses have fees lower than 1936 SGD                                |
# | **Upper Fence**  | 2676        | Values above this are considered outliers                                   |
# | **Max**          | 7875        | Extremely high-priced course(s)                                             |

# %%
# # Step 2: Clean the 'fees' column (remove $, commas, convert to numeric)
df['fees'] = df['fees'].astype(str).str.replace(r'[$,]', '', regex=True)

# Ensure 'fees' is numeric (in case it's stored as string with "$", ",", etc.)
df['fees'] = pd.to_numeric(df['fees'], errors='coerce')

# %%
# Drop missing values
fees_clean = df['fees'].dropna()

# Describe the fees
fees_summary = fees_clean.describe().round(2)

print(fees_summary)
# Out:
# count    1189.00
# mean     1739.81
# std       758.26
# min         0.00
# 25%      1392.00
# 50%      1461.00
# 75%      1936.00
# max      7875.00
# Name: fees, dtype: float64

# %% [markdown]
# ## Top expensive courses
#
# When ranked by course fees, the top 15 most expensive courses are primarily concentrated in the field of Business Administration, which accounts for 7 out of the 15 courses (46.7%). Notable examples include Business Economics and Public Policy, Marketing for the Future Economy, and Managing Technology and Innovation, each priced at SGD 7,875 with a duration of 6 months.
#
# The second most represented area is Science and Technology with 5 courses (33.3%), such as SAP Procurement, SAP Financials – Management Accounting, and SAP Financials – Financial Accounting, each priced at SGD 7,246.
#
# Social Services, Design, and Digital Media each appear once (6.67%). For instance, the Family Business: Navigating Success and Legacy course under Social Services is a short course costing SGD 3,900. Similarly, Collaborative Applied Project under Design and Audio and Video Production Techniques under Digital Media are included among the highest-priced offerings.

# %%
# Step 3: Drop rows where fees are missing
df_clean = df.dropna(subset=['fees'])

# Step 4: Sort by fees descending and select top 15
top_5_expensive = df_clean.sort_values(by='fees', ascending=False).head(15)

# %%
top_5_expensive
# Out:
#                                                  title       code  \
# 140               Business Economics and Public Policy   (ECO631)
# 528                   Marketing for the Future Economy   (MKT631)
# 524                 Managing Technology and Innovation   (BUS651)
# 661   Strategic Leadership & Management for Excellence   (BUS613)
# 617                                    SAP Procurement   (ICT374)
# 614               SAP Financials-Management Accounting   (ICT372)
# 613                SAP Financials-Financial Accounting   (ICT370)
# 276                      Collaborative Applied Project   (DES591)
# 235                                    Applied Project   (ANL588)
# 1172  Fundamentals of Contemporary Business Management   (CET257)
# 742         Executive Management Masterclass Programme   (CET180)
# 1037    Family Business: Navigating Success and Legacy  (CETW007)
# 554                         Oracle Certified Associate   (ICT255)
# 245              Audio and Video Production Techniques   (MTD301)
# 420                                     HCIA – Datacom   (ICT264)
#
#                                                                                                        url  \
# 140                                                          https://www.suss.edu.sg/courses/detail/eco631
# 528                                                          https://www.suss.edu.sg/courses/detail/mkt631
# 524                                                          https://www.suss.edu.sg/courses/detail/bus651
# 661                                                          https://www.suss.edu.sg/courses/detail/bus613
# 617                                                          https://www.suss.edu.sg/courses/detail/ict374
# 614                                                          https://www.suss.edu.sg/courses/detail/ict372
# 613                                                          https://www.suss.edu.sg/courses/detail/ict370
# 276                                                          https://www.suss.edu.sg/courses/detail/des591
# 235                                                          https://www.suss.edu.sg/courses/detail/anl588
# 1172  https://www.suss.edu.sg/courses/short-course/detail/fundamentals-of-contemporary-business-management
# 742         https://www.suss.edu.sg/courses/short-course/detail/executive-management-masterclass-programme
# 1037     https://www.suss.edu.sg/courses/short-course/detail/family-business-navigating-success-and-legacy
# 554                                                          https://www.suss.edu.sg/courses/detail/ict255
# 245                                                          https://www.suss.edu.sg/courses/detail/mtd301
# 420                                                          https://www.suss.edu.sg/courses/detail/ict264
#
#                                                     types  featured  \
# 140                               Modular Graduate Course     False
# 528                               Modular Graduate Course     False
# 524                               Modular Graduate Course     False
# 661                               Modular Graduate Course     False
# 617                          Modular Undergraduate Course     False
# 614                          Modular Undergraduate Course     False
# 613                          Modular Undergraduate Course     False
# 276        IHL Micro-Credentials, Modular Graduate Course     False
# 235        IHL Micro-Credentials, Modular Graduate Course     False
# 1172                    Short Course, SkillsFuture Series     False
# 742                                          Short Course     False
# 1037                                         Short Course     False
# 554   IHL Micro-Credentials, Modular Undergraduate Course     False
# 245   IHL Micro-Credentials, Modular Undergraduate Course     False
# 420   IHL Micro-Credentials, Modular Undergraduate Course     False
#
#      applications_open applications_close     intake     duration    fees  \
# 140          01-May-25          15-Jun-25     Jul-25     6 months  7875.0
# 528          01-May-25          15-Jun-25     Jul-25     6 months  7875.0
# 524          01-May-25          15-Jun-25     Jul-25     6 months  7875.0
# 661          01-May-25          15-Jun-25     Jul-25     6 months  7875.0
# 617          01-May-25          15-Jun-25     Jul-25     6 months  7246.0
# 614          01-May-25          15-Jun-25     Jul-25     6 months  7246.0
# 613          01-May-25          15-Jun-25     Jul-25     6 months  7246.0
# 276          01-May-25          15-Jun-25     Jul-25     6 months  5280.0
# 235          01-May-25          15-Jun-25     Jul-25    12 months  5280.0
# 1172         14-Sep-23          20-Feb-24  05-Mar-24       4 days  4400.0
# 742          17-Dec-24          07-Mar-25  28-Mar-25  3 full days  3960.0
# 1037         02-Aug-24          15-Oct-24  29-Oct-24       2 days  3900.0
# 554          01-May-25          15-Jun-25     Jul-25     6 months  3211.0
# 245          01-May-25          15-Jun-25     Jul-25     6 months  3211.0
# 420          01-May-25          15-Jun-25     Jul-25     6 months  3211.0
#
#              area_of_interest
# 140   Business Administration
# 528   Business Administration
# 524   Business Administration
# 661   Business Administration
# 617    Science and Technology
# 614    Science and Technology
# 613    Science and Technology
# 276                    Design
# 235   Business Administration
# 1172  Business Administration
# 742   Business Administration
# 1037          Social Services
# 554    Science and Technology
# 245             Digital Media
# 420    Science and Technology

# %%
top_5_expensive[['title','types','intake','duration','fees','area_of_interest']]
# Out:
#                                                  title  \
# 140               Business Economics and Public Policy
# 528                   Marketing for the Future Economy
# 524                 Managing Technology and Innovation
# 661   Strategic Leadership & Management for Excellence
# 617                                    SAP Procurement
# 614               SAP Financials-Management Accounting
# 613                SAP Financials-Financial Accounting
# 276                      Collaborative Applied Project
# 235                                    Applied Project
# 1172  Fundamentals of Contemporary Business Management
# 742         Executive Management Masterclass Programme
# 1037    Family Business: Navigating Success and Legacy
# 554                         Oracle Certified Associate
# 245              Audio and Video Production Techniques
# 420                                     HCIA – Datacom
#
#                                                     types     intake  \
# 140                               Modular Graduate Course     Jul-25
# 528                               Modular Graduate Course     Jul-25
# 524                               Modular Graduate Course     Jul-25
# 661                               Modular Graduate Course     Jul-25
# 617                          Modular Undergraduate Course     Jul-25
# 614                          Modular Undergraduate Course     Jul-25
# 613                          Modular Undergraduate Course     Jul-25
# 276        IHL Micro-Credentials, Modular Graduate Course     Jul-25
# 235        IHL Micro-Credentials, Modular Graduate Course     Jul-25
# 1172                    Short Course, SkillsFuture Series  05-Mar-24
# 742                                          Short Course  28-Mar-25
# 1037                                         Short Course  29-Oct-24
# 554   IHL Micro-Credentials, Modular Undergraduate Course     Jul-25
# 245   IHL Micro-Credentials, Modular Undergraduate Course     Jul-25
# 420   IHL Micro-Credentials, Modular Undergraduate Course     Jul-25
#
#          duration    fees         area_of_interest
# 140      6 months  7875.0  Business Administration
# 528      6 months  7875.0  Business Administration
# 524      6 months  7875.0  Business Administration
# 661      6 months  7875.0  Business Administration
# 617      6 months  7246.0   Science and Technology
# 614      6 months  7246.0   Science and Technology
# 613      6 months  7246.0   Science and Technology
# 276      6 months  5280.0                   Design
# 235     12 months  5280.0  Business Administration
# 1172       4 days  4400.0  Business Administration
# 742   3 full days  3960.0  Business Administration
# 1037       2 days  3900.0          Social Services
# 554      6 months  3211.0   Science and Technology
# 245      6 months  3211.0            Digital Media
# 420      6 months  3211.0   Science and Technology

# %%
# Count how many of each area_of_interest appears
area_counts = top_5_expensive['area_of_interest'].value_counts().reset_index()
area_counts.columns = ['Area of Interest', 'Number of Courses']

# Sort for color mapping: small values get light color, big ones get dark
area_counts = area_counts.sort_values(by='Number of Courses', ascending=True)
colors = px.colors.sequential.Blues[-len(area_counts):]

# Create pie chart
fig = px.pie(
    area_counts,
    names='Area of Interest',
    values='Number of Courses',
    title='Area of Interest Distribution in Top 15 Most Expensive Courses',
    color=area_counts['Area of Interest'],
    color_discrete_sequence=colors
)

fig.update_traces(textinfo='percent+label', textfont_size=14)
fig.update_layout(title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8921374-e624-4fc8-95a3-04e25834f77d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8921374-e624-4fc8-95a3-04e25834f77d")) {                    Plotly.newPlot(                        "f8921374-e624-4fc8-95a3-04e25834f77d",                        [{"customdata":[["Social Services"],["Design"],["Digital Media"],["Science and Technology"],["Business Administration"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Area of Interest=%{customdata[0]}\u003cbr\u003eNumber of Courses=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Social Services","Design","Digital Media","Science and Technology","Business Administration"],"legendgroup":"","marker":{"colors":["rgb(107,174,214)","rgb(66,146,198)","rgb(33,113,181)","rgb(8,81,156)","rgb(8,48,107)"]},"name":"","showlegend":true,"values":[1,1,1,5,7],"type":"pie","textfont":{"size":14},"textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"err ...

# %% [markdown]
# ## Short Courses Fees Analysis
#
# In the category of short courses, the top 15 most expensive offerings are predominantly focused on the area of Social Services, which accounts for 73.3% (11 out of 15 courses). This includes a range of counselling-related programmes such as Couple Counselling, Narrative Therapy in Family Counselling, and Counselling Children and Adolescents, each priced at approximately SGD 2400 for a duration of four days. Business Administration makes up 13.3% (2 courses), represented by courses like Executive Management Masterclass Programme. The remaining areas—Others and Business Administration, International Trade, Science and Technology—each contribute one course (6.67%), including programmes like Executive Leadership for Learning and Development Professionals and Counselling on Ageing Family Issues.

# %%
df_fees_des=df_clean.sort_values(by='fees', ascending=False)

# %%
df_fees_des['duration'].unique()
# Out:
# array(['6 months', '12 months', '4 days', '3 full days', '2 days',
#        '3 days', '1 day', '4 x half-day', '30 months'], dtype=object)

# %%
Short_Course_Fees = df_fees_des[~df_fees_des['duration'].isin(['6 months', '12 months', '30 months'])]
Top_15_Short_Course=Short_Course_Fees.head(15)
Top_15_Short_Course[['title','types','intake','duration','fees','area_of_interest']]
# Out:
#                                                                                    title  \
# 1172                                    Fundamentals of Contemporary Business Management
# 742                                           Executive Management Masterclass Programme
# 1037                                      Family Business: Navigating Success and Legacy
# 1051           Executive Leadership Programme for Learning and Development Professionals
# 155                 Human Development: A Psychosocial Approach (Classroom & Synchronous)
# 183   Couple Counselling: Emotionally - Focused Couple Therapy (Classroom & Synchronous)
# 1036                                            Micro and Advanced Skills in Counselling
# 1035                                              Theories and Techniques in Counselling
# 1136                                           Practicum: Specialised Counselling Skills
# 741                    Narrative Therapy in Family Counselling (Classroom & Synchronous)
# 740                                             Couple Counselling: The Gottman Approach
# 164                        Counselling on Ageing Family Issues (Classroom & Synchronous)
# 165                                  Structural Family Therapy (Classroom & Synchronous)
# 188                     Counselling in a Multicultural Context (Classroom & Synchronous)
# 158                       Counselling Children and Adolescents (Classroom & Synchronous)
#
#                                   types     intake     duration    fees  \
# 1172  Short Course, SkillsFuture Series  05-Mar-24       4 days  4400.0
# 742                        Short Course  28-Mar-25  3 full days  3960.0
# 1037                       Short Course  29-Oct-24       2 days  3900.0
# 1051                       Short Course  01-Oct-24       3 days  2800.0
# 155                        Short Course  05-Aug-25       4 days  2400.0
# 183                        Short Course  01-Sep-25       4 days  2400.0
# 1036                       Short Course  12-Feb-25       4 days  2400.0
# 1035                       Short Course  25-Feb-25       4 days  2400.0
# 1136  Short Course, SkillsFuture Series        TBC        1 day  2400.0
# 741                        Short Course  22-Apr-25       4 days  2400.0
# 740                        Short Course  08-Apr-25       4 days  2400.0
# 164                        Short Course  20-May-25       4 days  2400.0
# 165                        Short Course  06-May-25       4 days  2400.0
# 188                        Short Course  20-May-25       4 days  2400.0
# 158                        Short Course  13-May-25       4 days  2400.0
#
#                                                           area_of_interest
# 1172                                               Business Administration
# 742                                                Business Administration
# 1037                                                       Social Services
# 1051                                                                Others
# 155                                                        Social Services
# 183                                                        Social Services
# 1036                                                       Social Services
# 1035                                                       Social Services
# 1136                                                       Social Services
# 741                                                        Social Services
# 740                                                        Social Services
# 164   Business Administration, International Trade, Science and Technology
# 165                                                        Social Services
# 188                                                        Social Services
# 158                                                        Social Services

# %%
# Count how many of each area_of_interest appears
area_counts = Top_15_Short_Course['area_of_interest'].value_counts().reset_index()
area_counts.columns = ['Area of Interest', 'Number of Courses']

# Sort for color mapping: small values get light color, big ones get dark
area_counts = area_counts.sort_values(by='Number of Courses', ascending=True)
colors = px.colors.sequential.Blues[-len(area_counts):]

# Create pie chart
fig = px.pie(
    area_counts,
    names='Area of Interest',
    values='Number of Courses',
    title='Area of Interest Distribution in Top 15 Most Expensive Short Courses',
    color=area_counts['Area of Interest'],
    color_discrete_sequence=colors
)

fig.update_traces(textinfo='percent+label', textfont_size=14)
fig.update_layout(title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f999a7d-94cc-45eb-a472-86846f1dad15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f999a7d-94cc-45eb-a472-86846f1dad15")) {                    Plotly.newPlot(                        "9f999a7d-94cc-45eb-a472-86846f1dad15",                        [{"customdata":[["Business Administration, International Trade, Science and Technology"],["Others"],["Business Administration"],["Social Services"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Area of Interest=%{customdata[0]}\u003cbr\u003eNumber of Courses=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Business Administration, International Trade, Science and Technology","Others","Business Administration","Social Services"],"legendgroup":"","marker":{"colors":["rgb(66,146,198)","rgb(33,113,181)","rgb(8,81,156)","rgb(8,48,107)"]},"name":"","showlegend":true,"values":[1,1,2,11],"type":"pie","textfont":{"size":14},"textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outli ...

# %% [markdown]
# ## Distribution of Course Fees
#
# The majority of courses are priced within the range of SGD 1392 to SGD 1936, with  a  median fee of SGD 1461. While most course fees are clustered within this interquartile range, a number of outliers exist, including courses priced as high as SGD 7875.

# %%
import plotly.express as px

fig = px.box(
    df,
    y='fees',
    title='Distribution of Course Fees',
    points='outliers',
    labels={'fees': 'Course Fees (SGD)'},
    color_discrete_sequence=['#1f77b4']
)


fig.update_layout(
    yaxis_title='Course Fees (SGD)',
    title_x=0.5,
    font=dict(size=14),
    plot_bgcolor='rgba(0,0,0,0)',
    paper_bgcolor='rgba(0,0,0,0)'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cdb1897c-d6b5-4fa7-8041-f4598bf20f4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdb1897c-d6b5-4fa7-8041-f4598bf20f4d")) {                    Plotly.newPlot(                        "cdb1897c-d6b5-4fa7-8041-f4598bf20f4d",                        [{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Course Fees (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,1461.0,7875.0,1606.0,2640.0,2640.0,2640.0,1461.0,1320.0,1606.0,2640.0,1461.0,2640.0,1400.0,700.0,650.0,650.0,2400.0,650.0,700.0,2400.0,2100.0,1400.0,1400.0,650.0,650.0,2400.0,2400.0,700.0,1400.0,1400.0,700.0,700.0,700.0,700.0,650.0,700.0,1400.0,700.0,100.0,650.0,1400.0,1300.0,875.0,700.0,2400.0,1400.0,650.0,1750.0,650.0,2400.0,700.0,700.0,700.0,950.0,2100.0,700.0,1400.0,1629.0,1320.0,1461.0,1461.0,1629.0,1606.0,1461.0,2640.0,1629.0,1461.0,2640.0,1936.0,1461.0,1936.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,0.0,1461.0,3211.0,1461.0,1606.0,0.0,1936.0,1461.0,1461.0,1461.0,1461.0,1606.0,1606.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,5280.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,1629.0,3211.0,1606.0,1461.0,1461.0,1936.0,1606.0,1606.0,1606.0,1606.0,1606.0,1461.0,1461.0,1461.0,1461.0,1461.0,1606.0,1461.0,1461.0,1606.0,1606.0,2640.0,1320.0,2640.0,1461.0,2640.0,1461.0,1461.0,1606.0,1461.0,1461.0,1461.0,5280.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,2640.0,1606.0,1606.0,1461.0,1606.0,1320.0,1606.0,1461.0,1461.0,1606.0,1606.0,1461.0,1461.0,1320.0,1461.0,1461.0,1461.0,3000.0,1461.0,1461.0,2640.0,1461.0,1320.0,1606.0,1461.0,1461.0,1606.0,1461.0,1461.0,2676.0,1461.0,2640.0,1461.0,1461.0,2640.0,1320.0,1461.0,1461.0,1320.0,1606.0,1461.0,2640.0,2640.0,1461.0,2640.0,1606.0,1461.0,2640.0,1936.0,2640.0,1461.0,2640.0,1461.0,1936.0,1461.0,2640.0,1320.0,1461.0,1461.0,1936.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1606.0,1461.0,1461.0,1606.0,1461.0,1606.0,1606.0,1461.0,2640.0,1606.0,1461.0,1461.0,1461.0,1320.0,1461.0,1461.0,2640.0,1461.0,1461.0,1320.0,1629.0,1629.0,1461.0,2640.0,1461.0,2922.0,1461.0,2640.0,1606.0,1320.0,1461.0,1461.0,1320.0,3000.0,2640.0,1461.0,2200.0,2200.0,1606.0,1461.0,1936.0,1461.0,1461.0,732.0,732.0,1461.0,1461.0,1461.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1320.0,1461.0,3211.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,1320.0,2640.0,1320.0,1461.0,1461.0,1461.0,1461.0,1320.0,1461.0,1606.0,1320.0,1461.0,2640.0,1461.0,3000.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1629.0,1936.0,1461.0,1936.0,1320.0,1606.0,1461.0,1936.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,3185.05,1461.0,1606.0,2640.0,2640.0,2640.0,3000.0,3000.0,3000.0,3000.0,3000.0,2922.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,2 ...

# %%
import pandas as pd
import plotly.express as px

# Create fee buckets
bins = [0, 1000, 1500, 2000, 2500, 3000, 4000, 8000]
labels = ['0–1K', '1K–1.5K', '1.5K–2K', '2K–2.5K', '2.5K–3K', '3K–4K', '4K–8K']
df['fee_range'] = pd.cut(df['fees'], bins=bins, labels=labels, include_lowest=True)

# Count courses in each fee range
fee_counts = df['fee_range'].value_counts().sort_index().reset_index()
fee_counts.columns = ['Fee Range', 'Number of Courses']

# Sort by number of courses (ascending) to match color depth
fee_counts = fee_counts.sort_values(by='Number of Courses', ascending=True)

# Pick colors from a sequential scale (Blues from light to dark)
colors = px.colors.sequential.Blues[-len(fee_counts):]

# Create pie chart with mapped color sequence
fig = px.pie(
    fee_counts,
    names='Fee Range',
    values='Number of Courses',
    title='Course Fee Distribution by Range',
    color=fee_counts['Fee Range'],  # ensures color mapping works
    color_discrete_sequence=colors
)

# Formatting
fig.update_traces(textinfo='percent+label', textfont_size=14)
fig.update_layout(title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c1305fe-9ba0-4737-b4d2-b07efba435a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c1305fe-9ba0-4737-b4d2-b07efba435a9")) {                    Plotly.newPlot(                        "9c1305fe-9ba0-4737-b4d2-b07efba435a9",                        [{"customdata":[["4K–8K"],["3K–4K"],["2K–2.5K"],["0–1K"],["1.5K–2K"],["2.5K–3K"],["1K–1.5K"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Fee Range=%{customdata[0]}\u003cbr\u003eNumber of Courses=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["4K–8K","3K–4K","2K–2.5K","0–1K","1.5K–2K","2.5K–3K","1K–1.5K"],"legendgroup":"","marker":{"colors":["rgb(198,219,239)","rgb(158,202,225)","rgb(107,174,214)","rgb(66,146,198)","rgb(33,113,181)","rgb(8,81,156)","rgb(8,48,107)"]},"name":"","showlegend":true,"values":[10,17,47,56,139,214,706],"type":"pie","textfont":{"size":14},"textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color ...

# %% [markdown]
# ## Course Fee Distribution by Course Type
#
# Each horizontal box represents the distribution of course fees for a specific course type. The key components are:
#
# * Median:
# The line inside the box indicates the median (50th percentile). It divides the data into two equal halves — 50% of course fees are lower, and 50% are higher.
#
# * Box Edges (Quartiles):
#
#     - Left edge (Q1): 25th percentile — 25% of data points are below this value.
#
#     - Right edge (Q3): 75th percentile — 75% of data points are below this value.
#     - The box itself shows the interquartile range (IQR), where the middle 50% of the data is concentrated.
# *  "Whiskers":
# The lines extending from the box represent the minimum and maximum values within 1.5 times the IQR. They do not include outliers.
#
# * Outliers:
#
#   Small dots beyond the whiskers indicate extreme values, representing unusually high or low course fees — for example, exceptionally expensive or very cheap courses.

# %%
df_clean = df.dropna(subset=['fees', 'types'])  # ensure types column is not null

# Step 2: Plot box plot grouped by course type
fig = px.box(
    df_clean,
    x='fees',
    y='types',
    title='Course Fee Distribution by Course Type (Vertical)',
    labels={'types': 'Course Type', 'fees': 'Course Fee (SGD)'},
    points='outliers',
    color_discrete_sequence=['#1f77b4']  # single clean color
)

# Layout adjustments for clarity
fig.update_layout(
    xaxis_title='Course Fee (SGD)',
    yaxis_title='Course Type',
    title_x=0.5,
    font=dict(size=14),
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7d03611d-23dc-4eb0-b17e-c51436a754f2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d03611d-23dc-4eb0-b17e-c51436a754f2")) {                    Plotly.newPlot(                        "7d03611d-23dc-4eb0-b17e-c51436a754f2",                        [{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Course Fee (SGD)=%{x}\u003cbr\u003eCourse Type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1f77b4"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[1461.0,7875.0,1606.0,2640.0,2640.0,2640.0,1461.0,1320.0,1606.0,2640.0,1461.0,2640.0,1400.0,700.0,650.0,650.0,2400.0,650.0,700.0,2400.0,2100.0,1400.0,1400.0,650.0,650.0,2400.0,2400.0,700.0,1400.0,1400.0,700.0,700.0,700.0,700.0,650.0,700.0,1400.0,700.0,100.0,650.0,1400.0,1300.0,875.0,700.0,2400.0,1400.0,650.0,1750.0,650.0,2400.0,700.0,700.0,700.0,950.0,2100.0,700.0,1400.0,1629.0,1320.0,1461.0,1461.0,1629.0,1606.0,1461.0,2640.0,1629.0,1461.0,2640.0,1936.0,1461.0,1936.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,0.0,1461.0,3211.0,1461.0,1606.0,0.0,1936.0,1461.0,1461.0,1461.0,1461.0,1606.0,1606.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,5280.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,1629.0,3211.0,1606.0,1461.0,1461.0,1936.0,1606.0,1606.0,1606.0,1606.0,1606.0,1461.0,1461.0,1461.0,1461.0,1461.0,1606.0,1461.0,1461.0,1606.0,1606.0,2640.0,1320.0,2640.0,1461.0,2640.0,1461.0,1461.0,1606.0,1461.0,1461.0,1461.0,5280.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,2640.0,1606.0,1606.0,1461.0,1606.0,1320.0,1606.0,1461.0,1461.0,1606.0,1606.0,1461.0,1461.0,1320.0,1461.0,1461.0,1461.0,3000.0,1461.0,1461.0,2640.0,1461.0,1320.0,1606.0,1461.0,1461.0,1606.0,1461.0,1461.0,2676.0,1461.0,2640.0,1461.0,1461.0,2640.0,1320.0,1461.0,1461.0,1320.0,1606.0,1461.0,2640.0,2640.0,1461.0,2640.0,1606.0,1461.0,2640.0,1936.0,2640.0,1461.0,2640.0,1461.0,1936.0,1461.0,2640.0,1320.0,1461.0,1461.0,1936.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1606.0,1461.0,1461.0,1606.0,1461.0,1606.0,1606.0,1461.0,2640.0,1606.0,1461.0,1461.0,1461.0,1320.0,1461.0,1461.0,2640.0,1461.0,1461.0,1320.0,1629.0,1629.0,1461.0,2640.0,1461.0,2922.0,1461.0,2640.0,1606.0,1320.0,1461.0,1461.0,1320.0,3000.0,2640.0,1461.0,2200.0,2200.0,1606.0,1461.0,1936.0,1461.0,1461.0,732.0,732.0,1461.0,1461.0,1461.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1320.0,1461.0,3211.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,1320.0,2640.0,1320.0,1461.0,1461.0,1461.0,1461.0,1320.0,1461.0,1606.0,1320.0,1461.0,2640.0,1461.0,3000.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1629.0,1936.0,1461.0,1936.0,1320.0,1606.0,1461.0,1936.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,3185.05,1461.0,1606.0,2640.0,2640.0,2640.0,3000.0,3000.0,3000.0,3000.0,3000.0,2922.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1320.0,1461.0,1320.0,732.0,1320.0,1320.0,0.0,1461.0,1461.0,1461.0,1461.0,2640.0,1461.0,1936.0,1461.0,1461.0,1936.0,2640.0,1606.0,1461.0,1461.0,2922.0,1461.0,2640.0,1629.0,1461.0,1461.0,2640.0,7875.0,1461.0,1461.0,2640.0,7875.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1606.0,1461.0,1461.0,1461.0,1936.0,1320.0,1461.0,1461.0,1461.0,2640.0,2640.0,1461.0,1606.0,1606.0,1606.0,3211.0,1461.0,1461.0,3000.0,3000.0,3000.0,3000.0,1461.0,1461.0,1461.0,732.0,1461.0,1461.0,2640.0,2640.0,2640.0,2640.0,1461.0,1461.0,303.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,2640.0,1461.0,1461.0,2640.0,1461.0,1461.0,2640.0,1461.0,1606.0,1461.0,1461.0,2640.0,1461.0,1461.0,1 ...

# %% [markdown]
# # Intake
#
# Starting in 2025, there is a significant surge in course offerings, marking a major expansion in programme availability. As shown in the intake timeline, the number of courses jumps sharply from under 100 in previous years to over 1,000 in 2025, with the highest intake concentrated in July 2025 (721 courses) and January 2025 (319 courses). This dramatic increase reflects the institution's shift towards a more extensive and diversified educational strategy from that year onward.
#
# Looking at the areas of interest, Business Administration (227 courses), Science and Technology (178), Linguistics and Languages (117), and Humanities and Social Sciences (112) are the most prominent in 2025. These four domains alone account for a large share of the new offerings, signaling strategic emphasis on both industry-relevant skills and foundational academic disciplines.
#
# By contrast, while course availability continues into 2026 and beyond, the numbers are substantially lower. In 2026, the top areas remain consistent but at smaller scales—for example, Linguistics and Languages drops to 10 courses, and Adult Learning to 8 courses. A considerable portion of 2026–2027 offerings also fall under a “To be confirmed” category, with the largest share again in Linguistics and Languages and Adult Learning, suggesting tentative future planning or programmes in development.

# %%
# Count by intake period
df['intake'] = df['intake'].astype(str).str.replace(r'^\d{1,2}-', '', regex=True)
intake_counts = df['intake'].value_counts().reset_index()
intake_counts.columns = ['Intake Period', 'Number of Courses']
intake_counts = intake_counts.sort_values(by='Intake Period')
# Parse intake to datetime (using the first of the month as default)
df['intake_parsed'] = pd.to_datetime('01-' + df['intake'], format='%d-%b-%y', errors='coerce')

# Group and count by intake
intake_counts = df.groupby(['intake', 'intake_parsed']).size().reset_index(name='Number of Courses')

# Sort by actual datetime
intake_counts = intake_counts.sort_values(by='intake_parsed')

# Plot bar chart
fig = px.bar(
    intake_counts,
    x='intake',
    y='Number of Courses',
    title='Number of Courses by Intake Period (Chronological)',
    text='Number of Courses',
    color='Number of Courses',
    color_continuous_scale='Blues'
)

fig.update_layout(
    xaxis_title='Intake (Chronological)',
    yaxis_title='Number of Courses',
    title_x=0.5,
    font=dict(size=14),
    xaxis_tickangle=-45
)
fig.update_traces(textposition='outside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cdfd123c-08a2-4c03-bce1-3dd2c4f25742" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdfd123c-08a2-4c03-bce1-3dd2c4f25742")) {                    Plotly.newPlot(                        "cdfd123c-08a2-4c03-bce1-3dd2c4f25742",                        [{"alignmentgroup":"True","hovertemplate":"intake=%{x}\u003cbr\u003eNumber of Courses=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,1,1,10,14,1,26,71,1,2,1,19,2,1,1,16,2,3,2,2,1,319,4,1,6,14,3,721,5,8,5,3,46,8,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[2.0,1.0,1.0,10.0,14.0,1.0,26.0,71.0,1.0,2.0,1.0,19.0,2.0,1.0,1.0,16.0,2.0,3.0,2.0,2.0,1.0,319.0,4.0,1.0,6.0,14.0,3.0,721.0,5.0,8.0,5.0,3.0,46.0,8.0,2.0],"textposition":"outside","x":["Mar-19","Dec-19","Jul-21","Jan-22","Jul-22","Sep-22","Jan-23","Jul-23","Sep-23","Oct-23","Nov-23","Jan-24","Mar-24","Apr-24","Jun-24","Jul-24","Aug-24","Sep-24","Oct-24","Nov-24","Dec-24","Jan-25","Feb-25","Mar-25","Apr-25","May-25","Jun-25","Jul-25","Aug-25","Sep-25","Oct-25","Nov-25","Jan-26","Jul-26","Jan-27"],"xaxis":"x","y":[2,1,1,10,14,1,26,71,1,2,1,19,2,1,1,16,2,3,2,2,1,319,4,1,6,14,3,721,5,8,5,3,46,8,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %% [markdown]
# ## Future Courses by Area of Interest (2025 and Beyond)

# %%
df['intake_year'] = df['intake_parsed'].dt.year
future_courses = df[df['intake_year'] >= 2025]

# Drop missing area_of_interest
future_courses = future_courses.dropna(subset=['area_of_interest'])

# Group by year and area
grouped = future_courses.groupby(['intake_year', 'area_of_interest']).size().reset_index(name='Number of Courses')

# Create stacked bar chart (year on X, area on Y)
fig = px.bar(
    grouped,
    x='intake_year',
    y='Number of Courses',
    color='area_of_interest',
    title='Future Courses by Area of Interest (2025 and Beyond)',
    labels={'intake_year': 'Intake Year', 'area_of_interest': 'Area of Interest'},
    text='Number of Courses'
)

# Layout beautification
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Number of Courses',
    title_x=0.5,
    font=dict(size=14),
    barmode='stack'
)
fig.update_traces(textposition='inside')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c179f81c-4aa4-413c-bf4a-8aa6db20c97f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c179f81c-4aa4-413c-bf4a-8aa6db20c97f")) {                    Plotly.newPlot(                        "c179f81c-4aa4-413c-bf4a-8aa6db20c97f",                        [{"alignmentgroup":"True","hovertemplate":"Area of Interest=Adult Learning\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adult Learning","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Adult Learning","offsetgroup":"Adult Learning","orientation":"v","showlegend":true,"text":[30.0,8.0,2.0],"textposition":"inside","x":[2025.0,2026.0,2027.0],"xaxis":"x","y":[30,8,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Built Environment\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Built Environment","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Built Environment","offsetgroup":"Built Environment","orientation":"v","showlegend":true,"text":[49.0,3.0],"textposition":"inside","x":[2025.0,2026.0],"xaxis":"x","y":[49,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Business Administration\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business Administration","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Business Administration","offsetgroup":"Business Administration","orientation":"v","showlegend":true,"text":[227.0,7.0],"textposition":"inside","x":[2025.0,2026.0],"xaxis":"x","y":[227,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Business Administration, International Trade, Science and Technology\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business Administration, International Trade, Science and Technology","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Business Administration, International Trade, Science and Technology","offsetgroup":"Business Administration, International Trade, Science and Technology","orientation":"v","showlegend":true,"text":[9.0],"textposition":"inside","x":[2025.0],"xaxis":"x","y":[9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Compliance\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Compliance","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Compliance","offsetgroup":"Compliance","orientation":"v","showlegend":true,"text":[3.0],"textposition":"inside","x":[2025.0],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Design\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Design","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Design","offsetgroup":"Design","orientation":"v","showlegend":true,"text":[2.0],"textposition":"inside","x":[2025.0],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Area of Interest=Digital Media\u003cbr\u003eIntake Year=%{x}\u003cbr\u003eNumber of Courses=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Digital Media","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Digital Media","offsetgroup":"Digital Media","orientation":"v","showlegend":true,"text":[36.0,1.0],"textposition":"inside","x":[2025.0,2026.0],"xaxis":"x","y":[36, ...

# %%
# Filter rows where intake is "To be confirmed"
tbc_courses = df[df['intake'].astype(str).str.strip().str.lower() == 'to be confirmed']

# Group by area_of_interest
tbc_area_counts = tbc_courses['area_of_interest'].value_counts().reset_index()
tbc_area_counts.columns = ['Area of Interest', 'Number of TBC Courses']
sorted_tbc_area_counts = tbc_area_counts.sort_values(by='Number of TBC Courses', ascending=True)

fig = px.bar(
    sorted_tbc_area_counts,
    x='Number of TBC Courses',
    y='Area of Interest',
    orientation='h',
    title='Top Areas with "To be Confirmed" Intakes',
    text='Number of TBC Courses',
    color='Number of TBC Courses',
    color_continuous_scale='Blues'
)

fig.update_layout(
    xaxis_title='Number of Courses',
    yaxis_title='Area of Interest',
    title_x=0.5
)
fig.update_traces(textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bae7a317-bec5-4cb5-aec8-b53e65521bcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bae7a317-bec5-4cb5-aec8-b53e65521bcf")) {                    Plotly.newPlot(                        "bae7a317-bec5-4cb5-aec8-b53e65521bcf",                        [{"alignmentgroup":"True","hovertemplate":"Number of TBC Courses=%{marker.color}\u003cbr\u003eArea of Interest=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,2,3,3,3,3,4,4,4,6,7,8,8,11,15,16],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[1.0,2.0,3.0,3.0,3.0,3.0,4.0,4.0,4.0,6.0,7.0,8.0,8.0,11.0,15.0,16.0],"textposition":"outside","x":[1,2,3,3,3,3,4,4,4,6,7,8,8,11,15,16],"xaxis":"x","y":["Information Technology","Management","Digital Media","Built Environment","Science and Technology","Business Administration, International Trade, Science and Technology","Social Services","Humanities and Social Sciences","Others","To be confirmed","Design","Business Administration","Finance","General Studies","Adult Learning","Linguistics and Languages"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"o ...

# %%
type_counts = future_courses['types'].value_counts().reset_index()
type_counts.columns = ['Course Type', 'Number of Courses']

# Create horizontal bar chart
fig = px.bar(
    type_counts.sort_values(by='Number of Courses', ascending=True),  # smaller on top
    x='Number of Courses',
    y='Course Type',
    orientation='h',
    title='Distribution of Course Types in Future Intakes (2025 and Beyond)',
    text='Number of Courses',
    color='Number of Courses',
    color_continuous_scale='Blues'
)

# Layout tweaks
fig.update_layout(
    xaxis_title='Number of Courses',
    yaxis_title='Course Type',
    title_x=0.5,
    font=dict(size=13)
)

fig.update_traces(textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="59821162-ece2-4508-99b6-a0fb05300621" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59821162-ece2-4508-99b6-a0fb05300621")) {                    Plotly.newPlot(                        "59821162-ece2-4508-99b6-a0fb05300621",                        [{"alignmentgroup":"True","hovertemplate":"Number of Courses=%{marker.color}\u003cbr\u003eCourse Type=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,2,2,3,6,12,18,25,27,34,36,40,43,43,65,185,603],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[1.0,2.0,2.0,3.0,6.0,12.0,18.0,25.0,27.0,34.0,36.0,40.0,43.0,43.0,65.0,185.0,603.0],"textposition":"outside","x":[1,2,2,3,6,12,18,25,27,34,36,40,43,43,65,185,603],"xaxis":"x","y":["Certificate Course, Modular Graduate Course","Modular Undergraduate Course, SkillsFuture Series","Law Programmes","Certificate Course, IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Certificate Course, IHL Micro-Credentials, Modular Graduate Course","Full-time Undergraduate","Short Course","Graduate Certificate","IHL Micro-Credentials, Modular Graduate Course, SkillsFuture Series","Part-time Undergraduate","Short Course, SkillsFuture Series","Modular Undergraduate Course","IHL Micro-Credentials, Modular Undergraduate Course, SkillsFuture Series","Modular Graduate Course","Graduate Studies","IHL Micro-Credentials, Modular Graduate Course","IHL Micro-Credentials, Modular Undergraduate Course"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colors ...

# %%
# Drop missing fees and area_of_interest
fees_clean = future_courses.dropna(subset=['fees', 'area_of_interest']).copy()

# Step 1: Get ordering of areas by total course count (largest first)
area_order = (
    fees_clean['area_of_interest']
    .value_counts()
    .sort_values(ascending=False)
    .index.tolist()
)

# Step 2: Convert to ordered categorical (this controls stacking order)
fees_clean['area_of_interest'] = pd.Categorical(
    fees_clean['area_of_interest'],
    categories=area_order,
    ordered=True
)

# Step 3: Convert to string — important for Plotly to respect order
fees_clean['area_of_interest'] = fees_clean['area_of_interest'].astype(str)

# Step 4: Plot stacked histogram
fig = px.histogram(
    fees_clean,
    x='fees',
    nbins=40,
    title='Distribution of Course Fees by Area of Interest',
    labels={'fees': 'Course Fee (SGD)', 'area_of_interest': 'Area of Interest'},
    color='area_of_interest',
    barmode='stack'
)

fig.update_layout(
    xaxis_title='Course Fee (SGD)',
    yaxis_title='Number of Courses',
    title_x=0.5,
    font=dict(size=14),
    legend_title='Area of Interest'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d1761c2-9252-4af3-8cf0-f9473102469a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d1761c2-9252-4af3-8cf0-f9473102469a")) {                    Plotly.newPlot(                        "4d1761c2-9252-4af3-8cf0-f9473102469a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Area of Interest=Built Environment\u003cbr\u003eCourse Fee (SGD)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Built Environment","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Built Environment","nbinsx":40,"offsetgroup":"Built Environment","orientation":"v","showlegend":true,"x":[1461.0,2640.0,1461.0,1461.0,1461.0,1606.0,1606.0,1461.0,1461.0,1606.0,1461.0,1606.0,1461.0,1461.0,1461.0,2640.0,2640.0,1461.0,2640.0,1461.0,1461.0,1461.0,1461.0,1392.0,1529.0,2640.0,1529.0,1529.0,1529.0,1392.0,1529.0,1529.0,1392.0,1392.0,1392.0,2640.0,2640.0,1392.0,1392.0,1392.0,1392.0,1392.0,1392.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Area of Interest=Business Administration\u003cbr\u003eCourse Fee (SGD)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business Administration","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Business Administration","nbinsx":40,"offsetgroup":"Business Administration","orientation":"v","showlegend":true,"x":[7875.0,650.0,650.0,650.0,2100.0,1400.0,700.0,1400.0,700.0,700.0,700.0,700.0,1300.0,700.0,1400.0,700.0,2100.0,700.0,1629.0,1629.0,1629.0,1461.0,1461.0,5280.0,2640.0,1461.0,1461.0,1629.0,1461.0,1461.0,1461.0,1461.0,1320.0,3000.0,1461.0,2640.0,1461.0,2640.0,1461.0,1461.0,2640.0,1461.0,2640.0,2640.0,2640.0,1461.0,2640.0,1320.0,1461.0,1461.0,1320.0,1629.0,1629.0,3000.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,1461.0,1461.0,3000.0,1461.0,1629.0,1320.0,1461.0,1461.0,3000.0,3000.0,3000.0,3000.0,3000.0,1461.0,2640.0,1461.0,1461.0,2640.0,1461.0,1629.0,1461.0,7875.0,2640.0,7875.0,1461.0,1461.0,1320.0,1461.0,2640.0,1461.0,3000.0,3000.0,3000.0,3000.0,2640.0,1461.0,1461.0,1461.0,1461.0,1461.0,1320.0,1461.0,2640.0,1320.0,1461.0,1320.0,1461.0,1461.0,1461.0,1461.0,1461.0,1461.0,7875.0,1629.0,2640.0,1461.0,1461.0,1461.0,2640.0,1461.0,2640.0,2640.0,3960.0,2100.0,1551.0,1551.0,3000.0,2640.0,2640.0,1392.0,1392.0,1392.0,1392.0,1392.0,1392.0,1392.0,1392.0,3000.0,2640.0,1320.0,1320.0,1392.0,2640.0,2640.0,1392.0,2640.0,2640.0,1551.0,1551.0,1392.0,2640.0,1320.0,1392.0,1551.0,1392.0,3000.0,3000.0,2640.0,3000.0,1392.0,2640.0,1392.0,3000.0,2640.0,1392.0,1392.0,3000.0,3000.0,3000.0,1392.0,1392.0,1392.0,1320.0,1392.0,2640.0,1392.0,2640.0,2640.0,1551.0,2640.0,1551.0,1392.0,1392.0,1392.0,1392.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0,2640.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Area of Interest=Science and Technology\u003cbr\u003eCourse Fee (SGD)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Science and Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Science and Technology","nbinsx":40,"offsetgroup":"Science and Technology","orientation":"v","showlegend":true,"x":[1606.0,650.0,650.0,650.0,650.0,650.0,650.0,1400.0,1461.0,1461.0,1936.0,1461.0,1936.0,3211.0,1606.0,1936.0,1606.0,1461.0,1461.0,1461.0,1461.0,1936.0,1606.0,1606.0,1606.0,1606.0,1606.0,1461.0,1461.0,1606.0,1461.0,1606.0,1606.0,1461.0,1606.0,1461.0,1461.0,1461.0,1606.0,1606.0,1461.0,1606.0,1461.0,1606.0,1606.0,1936.0,1936.0,1936.0,1461.0,1461.0,1461.0,1606.0,1606.0,1606.0,1461.0,1606.0,1461.0,1606.0,1461.0,1606.0,1936.0,1461.0,1461.0,1461.0,1461.0,1461.0,3211.0,1 ...
